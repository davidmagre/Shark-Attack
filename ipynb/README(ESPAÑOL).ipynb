# %%
SHARK ATTACK ANALYSIS

Estamos analizando una base de datos que cuenta los ataques de tiburon. Para ello he realizado primero de todo una limpieza general de la tabla para poder llegar a los datos y las hipotesis reformuladas a continuación:

- Limpieza de duplicados, utilizando una función de drop dupicates.
- Limpieza de datos nulos en las filas, utilizando una función. En este caso el treshold es del 90%.
- Limpieza de las columnas no necesarias. Utilizando la función drop.

Quedandome con las siguientes columnas:
Dia, Mes, Año, Continente, Sexo, Año, Actividad, Especies, Tiempo del ataque, Tipo del ataque, Lesiones asociadas al ataque y la fatalidad.

Hypothesis 1
    a) Las especies de tiburones con más ataques son las que tienen un mayor indice de fatalidades
        --> Podria ser ya que a más ataques, más posibilidad de que estos sean fatales.
    
    b) Las especies de tiburones con mayores ataques no tienen un mayor indice de fatalidad.
        --> Ya que estas tienen mas encuentros con humanos y estan mas acostumbrados a su presencia por lo que los ataques suelen ser más defensivos y no acaban en fatalidad.

        VARIABLES A TENER EN CUENTA
        ESPECIES --> Primero de todo vemos cuales son las especies que registran mayor numero de ataques y solo tendremos en cuenta las que tengan un número significativamente relevante. Para limpiar la columna de las especies he utilizado una función de regex.
        NUMERO DE ATAQUES --> Número de ataques de los tiburones
      
        ![alt text](../H1_01_shark_attacks_per_species.png)

        Aqui vemos que hay 4 especies que tienen un numero significativo de ataques más alto que el resto que son 'White Shark', 'Tiger Shark', 'Bull Shark' y 'Blacktip Shark' y por ello son con las que trabajaremos.

        ![alt text](../H1_02_shark_attacks_per_species_filtered.png)

        FATAL (Y/N) --> 'Y' es que la victima del ataque ha muerto. 'N' es que la victima no ha muerto.

        METODO
        Testear si existe correlación entre las especies de tiburones con más ataques y el indice de fatalidades.

        Para ello hacemos un grafico de barras apiladas teniendo en cuenta las especies seleccionadas en el eje horizontal, mantenemos la visión de numero de ataques en el eje vertical y le añadimos la variable de fatalidad.
        
        ![alt text](../H1_03_number_of_attacks_per_species_by_fatality.png)

        CONCLUSIÓN

        En este caso vemos como la Hipotesis 1 (a) que apunta que las especies de tiburones con más ataques són las que tienen un mayor indice de fatalidades es correcta. Ya que vemos una correlación positiva entre la especie que tiene más ataques 'White Shark' es tambien la que tiene un mayor numero de fatalidades.


Hypothesis 2
    a) Hay más ataques de tiburones en los meses de verano porque la gente se baña en el mar más en verano
        --> Imporante tener en cuenta aquí los continentes para correlacionar en que meses cae verano, ya que no son los mismos meses   para todas las localizaciones.

        VARIABLES A TENER EN CUENTA
        CONTINENTE --> Para saber en que hemisferio se encuentra y ser preciso en la estación del mes del ataque. Importante tener en cuenta que para los países del hemisferio norte entendemos verano como (JUN,JUL,AGO,SEP) y para los del sur (DIC,ENE,FEB,MAR).
        NUMERO DE ATAQUES --> Número de ataques de los tiburones

        Importante tener en cuenta que continentes tienen una muestra significativa para tenerlos en cuenta en la medición

        ![alt text](../H2_01_number_of_attacks_per_continent.png)

        Ahora vemos que los continentes con muestras significativas son 'America del Norte', 'Africa' y 'Oceania'.

        MONTH --> Meses del año en los que ocurren los ataques. Expresados en valor numerico del 1 al 12.

        METODO
        Testear si existe correlacion entre los meses de verano con el numero de ataques de tiburones en los continentes más representativos con un grafico multiple por barras en los que tenemos 3 graficos uno para cada continente. En los ejes verticales aparecen el numero de ataques mientras en los horizontales aparecen los meses para poder ver la dispersión de ataque por mes de forma clara.

       ![alt text](../H2_02_number_of_attacks_selected_continents.png)

        CONCLUSIÓN

        Aqui si que vemos como existe correlación positiva entre meses de verano y ataques. 
        
        En el caso de America del Norte continente en el hemisferio Norte con meses de verano que comprenden (JUN,JUL,AGO) y en los que en el grafico apreciamos que tiene sus picos de ataques en los meses de Agosto y Septiembre (junto con Octubre). 
        
        En el caso de los continentes del hemisferio Sur vemos mayor igualdad entre meses lo cual se puede explicar por su mayor cercania al eje del ecuador y por ende climas más tropicales. Sin embargo, en ambos continentes analizados tanto Africa como Oceania se observan mayores incidencias en los meses de verano que comprenden desde Diciembre a Marzo.

        En el caso de Oceania si se ve mas claramente esta diferencia entre meses ya que cuenta con un clima menos tropical con una mayor diferenciacion climatica entre estaciones. En Africa soprende ver los datos de Junio y Julio que estan casi a la altura de los meses de Invierno. Lo cual viene explicado por una menor diferencia de temperatura entre estaciones.


Hypothesis 3
    a) Los tiburones atacan más durante el dia ya que es cuando hay un mayor numero de bañistas o potenciales estorbos.
        aa) Durante la mañana, porque es cuando hay mas horas de sol y por ende la gente se baña más.
        ab) Durante la tarde, porque durante la mañana la gente trabaja y no se baña.
    b) Los tiburones atacan más cuando no hay luz de dia ya que es cuando salen a cazar ('Evening' y 'Night').

        VARIABLES A TENER EN CUENTA
        TIME --> Momentos del dia del ataque en los que se comprenden las variables de 'Morning', 'Afternoon', 'Evening' y 'Night'.
        NUMERO DE ATAQUES --> Número de ataques de los tiburones

        METODO
        Ver en que momento del dia se dan más ataques de tiburones

        ![alt text](../H3_01_number_of_attacks_moment_of_day.png)

        Tambien podemos añadir la variable de fatalidad al analisis para ver en que momento del dia se dan un mayor numero de muertes.

        ![alt text](../H3_02_number_of_attacks_moment_of_day_and_fatality.png)

        CONCLUSIÓN

        Aqui vemos como la hipotesis (a) es la correcta ya que hay un mayor numero de ataques en momentos de luz del dia. Ya que es cuando hay más bañistas. Así que descartamos la hipotesis que dice que hay más ataques cuando no hay luz.

        Dentro de la hipotesis (a) encontramos dos sub-hipotesis. Y vemos que  el momento del dia donde se dan más ataques es por la tarde (ab), donde podemos correlacionar que existe una mayor disponibilidad por parte de las posibles victimas para efectuar actividades acuaticas. Ya que la tarde es comunmente asociada como la parte del dia donde se realizan un mayor numero de actividades de ocio. Aunque no vemos mucha diferencia con los ataques que se dan en la mañana (aa). Por lo que podemos asegurar que la luz del dia es un factor diferencial para que sucedan los ataques.

        Analizando la correlacion con las fatalidades no encontramos nada significativo ya que vemos que la relacion de muertes por momento del dia es proporcional al numero de ataques que se han dado en ese momento del dia.


Hypothesis 4
    a) Las actividades o deportes acuaticos con tablas són más propensos a recibir ataques por parte de tiburones (más que nadar libremente). Ya que los tiburones confunden las tablas o paddle boards con presas y atacan porque se sienten amenazados.

        VARIABLES A TENER EN CUENTA
        ACTIVITY --> Actividades de las victimas en el momento del ataque
        NUMERO DE ATAQUES --> Número de ataques de los tiburones

        ![alt text](../H4_01_number_of_attacks_per_activity.png)

        Aqui vemos el numero de ataques por actividad. Escogemos actividades como muestras significativas que nos ayuden a analizar nuestra hipotesis cogiendo las 5 con más ataques. Además estas 5 las podemos agrupar en 2 sub-grupos. Las que forman parte de actividad o deportes con tablas ('Surfing' y 'Body boarding') y el resto que podriamos asociar con un ocio más libre que comprenden ('Fishing', 'Swimming' y 'Diving').

        INJURY --> Para ver la gravedad o tipo de lesiones que inflingen cada actividad. En este caso tenemos una escala de injuries de menor gravedad ('Unharmed') a mayor ('Fatal').

        METODO
        Testear si los deportes acuaticos de tabla suponen una mayor amenaza y la peligrosidad hacia el animal y el grado de las lesiones asociadas al ataque. Para ello hacemos un heatmap correlacionando las actividades en el eje vertical con el rango de lesiones ordenadas por orden de gravedad. 

        ![alt text](../H4_02_heatmap_activity_injury.png)

        Hay dos visiones incluidas una del 1 al 50 entendiendo el numero de ataques. Siendo 1 menor correlacion y 50 mayor correlacion.

        ![alt text](../H4_03_heatmap_activity_injury_01.png)

        La otra del 0 al 1. Siendo 0 menor correlacion y 1 una mayor correlacion.

        CONCLUSIÓN

        En este grafico podemos sacar varias conclusiones, pero la primera es ver que nuestra Hipotesis no es acertada. Ya que como vemos en la variable de actividad 'Surfing' existe la correlacion mas alta de todas las actividades con el menor riesgo 'Unharmed'. Esta está muy a la par con lesiones como 'Laceration' y 'Bite' pero con una gran diferencia a nivel correlacion con muertes. 
        No apreciamos mucho dato significativo para la actividad 'Body boarding'.

        Para el bloque actividades de ('Fishing', 'Swimming' y 'Diving') si que vemos una mayor correlacion asociada con lesiones más graves y sobretodo fatales. Por lo que asociamos una mayor peligrosidad en este tipo de actividades, contrariamente a lo que habiamos aseverado en nuestra hipotesis.

 OTRAS CONSIDERACIONES Y CONCLUSIÓN GENERAL

       - Hemos podido contestar de forma clara con material grafico las preguntas asociadas a las hipotesis. Así que podemos considerar que hemos logrado el objetivo.

       - Tener en cuenta la temperatura por si correlaciona con una mayor agresividad del animal o no.
